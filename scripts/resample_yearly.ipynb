# %% [markdown]
# ### imports and setup

# %%
# %load_ext autoreload 
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
from utils import *
from exploration import *

# %% [markdown]
# ### load data

# %%
monthly_data, yearly_data = load_dataset()

# %%
monthly_data
# Out:
#             date                      area  average_price       code  \
# 301   1995-01-01      barking and dagenham          50460  E09000002
# 302   1995-02-01      barking and dagenham          51086  E09000002
# 303   1995-03-01      barking and dagenham          51269  E09000002
# 304   1995-04-01      barking and dagenham          53134  E09000002
# 305   1995-05-01      barking and dagenham          53042  E09000002
# ...          ...                       ...            ...        ...
# 11438 2019-09-01  yorkshire and the humber         165362  E12000003
# 11439 2019-10-01  yorkshire and the humber         166669  E12000003
# 11440 2019-11-01  yorkshire and the humber         164530  E12000003
# 11441 2019-12-01  yorkshire and the humber         166932  E12000003
# 11442 2020-01-01  yorkshire and the humber         165383  E12000003
#
#        houses_sold  no_of_crimes  borough_flag  average_price_d1  year  month  \
# ...

# %%
yearly_data
# Out:
#            code                      area       date  median_salary  \
# 1     E09000002      barking and dagenham 1999-12-01        21480.0
# 52    E09000002      barking and dagenham 2000-12-01        22618.0
# 103   E09000002      barking and dagenham 2001-12-01        22323.0
# 154   E09000002      barking and dagenham 2002-12-01        24813.0
# 205   E09000002      barking and dagenham 2003-12-01        25358.0
# ...         ...                       ...        ...            ...
# 851   E12000003  yorkshire and the humber 2015-12-01        25194.0
# 902   E12000003  yorkshire and the humber 2016-12-01        25946.0
# 953   E12000003  yorkshire and the humber 2017-12-01        26309.0
# 1004  E12000003  yorkshire and the humber 2018-12-01        26892.0
# 1055  E12000003  yorkshire and the humber 2019-12-01        27835.0
#
#       life_satisfaction mean_salary recycling_pct  population_size  \
# 1                   NaN       23620             3         162444.0
# ...

# %%
df = yearly_data.groupby('area').resample('M', on='date', origin='start').mean(numeric_only=True).interpolate().reset_index()#.to_csv('housing_in_london_yearly_variables_resampled.csv')

# %%
df
# Out:
#                            area       date  median_salary  life_satisfaction  \
# 0          barking and dagenham 1999-12-31   21480.000000                NaN
# 1          barking and dagenham 2000-01-31   21574.833333                NaN
# 2          barking and dagenham 2000-02-29   21669.666667                NaN
# 3          barking and dagenham 2000-03-31   21764.500000                NaN
# 4          barking and dagenham 2000-04-30   21859.333333                NaN
# ...                         ...        ...            ...                ...
# 12286  yorkshire and the humber 2019-08-31   27520.666667                7.7
# 12287  yorkshire and the humber 2019-09-30   27599.250000                7.7
# 12288  yorkshire and the humber 2019-10-31   27677.833333                7.7
# 12289  yorkshire and the humber 2019-11-30   27756.416667                7.7
# 12290  yorkshire and the humber 2019-12-31   27835.000000                7.7
#
# ...

# %%
df.date
# Out:
# 0       1999-12-31
# 1       2000-01-31
# 2       2000-02-29
# 3       2000-03-31
# 4       2000-04-30
#            ...
# 12286   2019-08-31
# 12287   2019-09-30
# 12288   2019-10-31
# 12289   2019-11-30
# 12290   2019-12-31
# Name: date, Length: 12291, dtype: datetime64[ns]
